# %%
from lameg.surf import postprocess_freesurfer_surfaces
import numpy as np
import spm_standalone

# %%
# %env SUBJECTS_DIR=/home/common/bonaiuto/cued_action_meg/derivatives/processed/fs/
# Out:
# env: SUBJECTS_DIR=/home/common/bonaiuto/cued_action_meg/derivatives/processed/fs/

# %%
postprocess_freesurfer_surfaces(
    'sub-001',
    '/home/common/bonaiuto/cued_action_meg/derivatives/processed/sub-001/agm_surf/',
    'multilayer.11.ds.link_vector.fixed.gii',
    n_surfaces=11,
    ds_factor=0.11,
    orientation='link_vector',
    fix_orientation=True,
    remove_deep=True,
    n_jobs=-1
)
# Out:
# Saving /home/common/bonaiuto/cued_action_meg/derivatives/processed/sub-001/agm_surf/lh.pial.gii as a surface
# Saving /home/common/bonaiuto/cued_action_meg/derivatives/processed/sub-001/agm_surf/rh.pial.gii as a surface
# Saving /home/common/bonaiuto/cued_action_meg/derivatives/processed/sub-001/agm_surf/lh.0.900.gii as a surface
# Saving /home/common/bonaiuto/cued_action_meg/derivatives/processed/sub-001/agm_surf/rh.0.900.gii as a surface
# Saving /home/common/bonaiuto/cued_action_meg/derivatives/processed/sub-001/agm_surf/lh.0.800.gii as a surface
# Saving /home/common/bonaiuto/cued_action_meg/derivatives/processed/sub-001/agm_surf/rh.0.800.gii as a surface
# Saving /home/common/bonaiuto/cued_action_meg/derivatives/processed/sub-001/agm_surf/lh.0.700.gii as a surface
# Saving /home/common/bonaiuto/cued_action_meg/derivatives/processed/sub-001/agm_surf/rh.0.700.gii as a surface
# Saving /home/common/bonaiuto/cued_action_meg/derivatives/processed/sub-001/agm_surf/lh.0.600.gii as a surface
# Saving /home/common/bonaiuto/cued_action_meg/derivatives/processed/sub-001/agm_surf/rh.0.600.gii as a surface
# Saving /home/common/bonaiuto/cued_action_meg/derivatives/processed/sub-001/agm_surf/lh.0.500.gii as a surface
# Saving /home/common/bonaiuto/cued_action_meg/derivatives/processed/sub-001/agm_surf/rh.0.500.gii as a surface
# Saving /home/common/bonaiuto/cued_action_meg/derivatives/processed/sub-001/agm_surf/lh.0.400.gii as a surface
# Saving /home/common/bonaiuto/cued_action_meg/derivatives/processed/sub-001/agm_surf/rh.0.400.gii as a surface
# Saving /home/common/bonaiuto/cued_action_meg/derivatives/processed/sub-001/agm_surf/lh.0.300.gii as a surface
# Saving /home/common/bonaiuto/cued_action_meg/derivatives/processed/sub-001/agm_surf/rh.0.300.gii as a surface
# Saving /home/common/bonaiuto/cued_action_meg/derivatives/processed/sub-001/agm_surf/lh.0.200.gii as a surface
# Saving /home/common/bonaiuto/cued_action_meg/derivatives/processed/sub-001/agm_surf/rh.0.200.gii as a surface
# Saving /home/common/bonaiuto/cued_action_meg/derivatives/processed/sub-001/agm_surf/lh.0.100.gii as a surface
# Saving /home/common/bonaiuto/cued_action_meg/derivatives/processed/sub-001/agm_surf/rh.0.100.gii as a surface
# Saving /home/common/bonaiuto/cued_action_meg/derivatives/processed/sub-001/agm_surf/lh.white.gii as a surface
# Saving /home/common/bonaiuto/cued_action_meg/derivatives/processed/sub-001/agm_surf/rh.white.gii as a surface
# Saving /home/common/bonaiuto/cued_action_meg/derivatives/processed/sub-001/agm_surf/lh.inflated.gii as a surface
# Saving /home/common/bonaiuto/cued_action_meg/derivatives/processed/sub-001/agm_surf/rh.inflated.gii as a surface
# 100.0% of the vertices in the decimated surface belong to the original surface.

# %%
spm = spm_standalone.initialize()

# %%
_ = spm.spm_eeg_smoothmesh_multilayer_mm(
    '/home/common/bonaiuto/cued_action_meg/derivatives/processed/sub-001/agm_surf/multilayer.11.ds.link_vector.fixed.gii',
    float(5.0),
    float(11),
    nargout=1
)
# Out:
# smoothmeshname =
#
#     '/home/common/bonaiuto/cued_action_meg/derivatives/processed/sub-001/agm_surf/FWHM5.00_multilayer.11.ds.link_vector.fixed.mat'
#
#
#  FWHM of 5.00 is approx 2.67 times vertex spacing
#
#  Smoothing with fwhm 5.00 (1 of 1) this make take some time (~20mins per FWHM with parallel toolbox)
#
#  Layer 1Starting parallel pool (parpool) using the 'local' profile ...
# Connected to the parallel pool (number of workers: 32).
#
#  Layer 2
#  Layer 3
#  Layer 4
#  Layer 5
#  Layer 6
#  Layer 7
#  Layer 8

# %%
layers = np.linspace(1, 0, 11)
layer_fnames=[]
for layer in layers:
    if layer == 1:
        layer_fnames.append(
            '/home/common/bonaiuto/cued_action_meg/derivatives/processed/sub-001/agm_surf/pial.ds.link_vector.fixed.gii'
        )
    elif 0 < layer < 1:
        layer_fnames.append(
            f'/home/common/bonaiuto/cued_action_meg/derivatives/processed/sub-001/agm_surf/{layer:.3f}.ds.link_vector.fixed.gii'
        )
    elif layer == 0:
        layer_fnames.append(
            '/home/common/bonaiuto/cued_action_meg/derivatives/processed/sub-001/agm_surf/white.ds.link_vector.fixed.gii'
        )
print(layer_fnames)
# Out:
# ['/home/common/bonaiuto/cued_action_meg/derivatives/processed/sub-001/agm_surf/pial.ds.link_vector.fixed.gii', '/home/common/bonaiuto/cued_action_meg/derivatives/processed/sub-001/agm_surf/0.900.ds.link_vector.fixed.gii', '/home/common/bonaiuto/cued_action_meg/derivatives/processed/sub-001/agm_surf/0.800.ds.link_vector.fixed.gii', '/home/common/bonaiuto/cued_action_meg/derivatives/processed/sub-001/agm_surf/0.700.ds.link_vector.fixed.gii', '/home/common/bonaiuto/cued_action_meg/derivatives/processed/sub-001/agm_surf/0.600.ds.link_vector.fixed.gii', '/home/common/bonaiuto/cued_action_meg/derivatives/processed/sub-001/agm_surf/0.500.ds.link_vector.fixed.gii', '/home/common/bonaiuto/cued_action_meg/derivatives/processed/sub-001/agm_surf/0.400.ds.link_vector.fixed.gii', '/home/common/bonaiuto/cued_action_meg/derivatives/processed/sub-001/agm_surf/0.300.ds.link_vector.fixed.gii', '/home/common/bonaiuto/cued_action_meg/derivatives/processed/sub-001/agm_surf/0.200.ds.link_vector.fixed.gii', '/home/common/bonaiuto/cued_action_meg/derivatives/processed/sub-001/agm_surf/0.100.ds.link_vector.fixed.gii', '/home/common/bonaiuto/cued_action_meg/derivatives/processed/sub-001/agm_surf/white.ds.link_vector.fixed.gii']

# %%
for layer_fname in layer_fnames:
     _ = spm.spm_eeg_smoothmesh_multilayer_mm(
        layer_fname,
        float(5.0),
        float(1),
        nargout=1
    )
# Out:
# smoothmeshname =
#
#     '/home/common/bonaiuto/cued_action_meg/derivatives/processed/sub-001/agm_surf/FWHM5.00_pial.ds.link_vector.fixed.mat'
#
#
#  FWHM of 5.00 is approx 2.44 times vertex spacing
#
#  Smoothing with fwhm 5.00 (1 of 1) this make take some time (~20mins per FWHM with parallel toolbox)
#
#  Layer 1Starting parallel pool (parpool) using the 'local' profile ...
#
# The command was cancelled.
#
# smoothmeshname =
#
#     '/home/common/bonaiuto/cued_action_meg/derivatives/processed/sub-001/agm_surf/FWHM5.00_0.900.ds.link_vector.fixed.mat'
#
# The command was cancelled.
#
# smoothmeshname =
#
#     '/home/common/bonaiuto/cued_action_meg/derivatives/processed/sub-001/agm_surf/FWHM5.00_0.800.ds.link_vector.fixed.mat'
#
#
#  FWHM of 5.00 is approx 2.53 times vertex spacing
#
#  Smoothing with fwhm 5.00 (1 of 1) this make take some time (~20mins per FWHM with parallel toolbox)
#
#  Layer 1Starting parallel pool (parpool) using the 'local' profile ...
